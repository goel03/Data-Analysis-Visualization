# %%
import pandas as pd

# %%
df=pd.DataFrame({'Name':["a","b","c"],
                 'gender':['M','f','M'],"BIRTH_MONTH":['dec',"jan","oct"],"passdiv":["III","I","I"]})

# %%
df
# Out:
#   Name gender BIRTH_MONTH passdiv
# 0    a      M         dec     III
# 1    b      f         jan       I
# 2    c      M         oct       I

# %%
pd.get_dummies(df[['gender','passdiv']])
# Out:
#    gender_M  gender_f  passdiv_I  passdiv_III
# 0         1         0          0            1
# 1         0         1          1            0
# 2         1         0          1            0

# %%
pd.get_dummies(df['passdiv'])
# Out:
#    I  III
# 0  0    1
# 1  1    0
# 2  1    0

# %%
#part b

# %%
df.sort_values(by="BIRTH_MONTH")
a = df['BIRTH_MONTH'].astype('category')
a
# Out:
# 0    dec
# 1    jan
# 2    oct
# Name: BIRTH_MONTH, dtype: category
# Categories (3, object): ['dec', 'jan', 'oct']

# %%
month_cat=["jan","oct","dec"]

df["BIRTH_MONTH"]=pd.Categorical(df["BIRTH_MONTH"],categories=month_cat)

# %%
df.sort_values(by="BIRTH_MONTH")
# Out:
#   Name gender BIRTH_MONTH passdiv
# 1    b      f         jan       I
# 2    c      M         oct       I
# 0    a      M         dec     III

# %% [markdown]
# question 8

# %%
df=pd.DataFrame({'Name':["a","b","a","b"],
                 'gender':['f','f','f',"M"],"mothlyin":[2333,1222,1111,1111]})

# %%
df
# Out:
#   Name gender  mothlyin
# 0    a      f      2333
# 1    b      f      1222
# 2    a      f      1111
# 3    b      M      1111

# %%
df.max()
# Out:
# Name           b
# gender         f
# mothlyin    2333
# dtype: object

# %%
s=df.groupby(by=["Name"])["mothlyin"].sum()

# %%
s
# Out:
# Name
# a    3444
# b    2333
# Name: mothlyin, dtype: int64

# %%
d=pd.DataFrame(df,columns=['Name','mothlyin'])

# %%
d
# Out:
#   Name  mothlyin
# 0    a      2333
# 1    b      1222
# 2    a      1111
# 3    b      1111

# %%
s=df.groupby(by=["Name"]).apply(print)
#df['gender'].isin(['f']).groupby(by="Name").max()
# Out:
#   Name gender  mothlyin
# 0    a      f      2333
# 2    a      f      1111
#   Name gender  mothlyin
# 1    b      f      1222
# 3    b      M      1111

# %%
s

# %%
s.max()
# Out:
# 2333

# %%
s2=df.max()

# %%
s2
# Out:
# Name           b
# gender         f
# mothlyin    2333
# dtype: object

# %%
df[df['mothlyin']>1111]
# Out:
#   Name gender  mothlyin
# 0    a      M      2333
# 1    b      f      1222

# %%
#part d

# %%
k=df.groupby('Name').agg({"mothlyin":"mean"})

# %%
k
# Out:
#       mothlyin
# Name
# a       1722.0
# b       1166.5

# %%
f=df["Name"]

f
# Out:
# 0    a
# 1    b
# 2    a
# 3    b
# Name: Name, dtype: object

# %%
f=df.loc[df["Name"]=="a"]

# %%
df.iloc[0:,1:2]
# Out:
#   gender
# 0      f
# 1      f
# 2      f
# 3      M

# %%
f
# Out:
#   Name gender  mothlyin
# 0    a      f      2333
# 2    a      f      1111

# %%
d=f.loc[df["gender"]=="f"]

# %%
d
# Out:
#   Name gender  mothlyin
# 0    a      f      2333
# 2    a      f      1111

# %%
s=d.groupby(by=["Name"])["mothlyin"].mean()

# %%
s
# Out:
# Name
# a    1722.0
# Name: mothlyin, dtype: float64
