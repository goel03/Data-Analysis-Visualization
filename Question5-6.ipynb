# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Iris.csv')
df.head()
df["Species"].value_counts().plot.bar()
#df.plot.bar()
#plt.xlabel("Class")
#plt.ylabel("Frequency")
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
import seaborn as sns

# %%
df.plot.bar(x="PetalWidthCm",y="SepalWidthCm")
# Out:
# <AxesSubplot:xlabel='PetalWidthCm'>

# %%
sns.scatterplot(data=df,x="PetalWidthCm",y="SepalWidthCm")
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='SepalWidthCm'>

# %%
#paert c

# %%
sns.distplot(df['PetalLengthCm'],bins=100,color='k')
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>

# %%
#part d

# %%
sns.pairplot(df)

# %% [markdown]
# QUESTION 6

# %%
#PART A

# %%
df1=pd.read_csv('weather.csv')
df1.head()
# Out:
#    Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                0.00  2016-01-03           1             3       2016
# 1                0.00  2016-01-03           1             3       2016
# 2                0.16  2016-01-03           1             3       2016
# 3                0.00  2016-01-03           1             3       2016
# 4                0.01  2016-01-03           1             3       2016
#
#   Station.City Station.Code Station.Location Station.State  \
# 0   Birmingham          BHM   Birmingham, AL       Alabama
# 1   Huntsville          HSV   Huntsville, AL       Alabama
# 2       Mobile          MOB       Mobile, AL       Alabama
# 3   Montgomery          MGM   Montgomery, AL       Alabama
# 4    Anchorage          ANC    Anchorage, AK        Alaska
#
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 0                         39                         46
# 1                         39                         47
# ...

# %%
#df1.groupby('Summary')['Humidity'].mean()

# %%
#df1['Humidity'].astype('category')

# %%
from datetime import datetime

# %%
y = df1.set_index('Date.Full')

# %%
df1.groupby('Date.Full',as_index=False)['Data.Temperature.Avg Temp'].mean()

# %%
 df1
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
df1.isnull().sum()
# Out:
# Data.Precipitation           0
# Date.Full                    0
# Date.Month                   0
# Date.Week of                 0
# Date.Year                    0
# Station.City                 0
# Station.Code                 0
# Station.Location             0
# Station.State                0
# Data.Temperature.Avg Temp    0
# Data.Temperature.Max Temp    0
# Data.Temperature.Min Temp    0
# Data.Wind.Direction          0
# Data.Wind.Speed              0
# dtype: int64

# %%
#part b

# %%
df1.replace(2017,np.nan).fillna(method='ffill')
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3     2016.0
# 1                    0.00  2016-01-03           1             3     2016.0
# 2                    0.16  2016-01-03           1             3     2016.0
# 3                    0.00  2016-01-03           1             3     2016.0
# 4                    0.01  2016-01-03           1             3     2016.0
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1     2016.0
# 16739                0.00  2017-01-01           1             1     2016.0
# 16740                0.00  2017-01-01           1             1     2016.0
# 16741                0.06  2017-01-01           1             1     2016.0
# 16742                0.10  2017-01-01           1             1     2016.0
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
# c part

# %%
data = "2016"

# %%
#t[.to_string()

# %%
time_object = datetime.strptime(data, '%Y').date()
print(time_object)
# Out:
# 2016-01-01

# %%
#part d

# %%
df1['Station.City'].groupby(df1['Station.Code']).apply(print)

# %%
#part e

# %%
groups=df1.groupby(['Data.Precipitation',pd.cut(df1['Data.Temperature.Avg Temp'],3)])

# %%
groups.size()
# Out:
# Data.Precipitation  Data.Temperature.Avg Temp
# 0.00                (-27.127, 15.333]             134
#                     (15.333, 57.667]             1569
#                     (57.667, 100.0]              2621
# 0.01                (-27.127, 15.333]              21
#                     (15.333, 57.667]              257
#                                                  ...
# 15.19               (15.333, 57.667]                0
#                     (57.667, 100.0]                 1
# 20.89               (-27.127, 15.333]               0
#                     (15.333, 57.667]                0
#                     (57.667, 100.0]                 1
# Length: 1695, dtype: int64
